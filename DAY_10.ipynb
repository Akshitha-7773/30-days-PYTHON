# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-7773/30-days-PYTHON/blob/main/DAY_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **strings**

# %%
name = "Akshitha"
print(name)
# Out:
# Akshitha

# %%
name = "Aki"
print(name[0])   # first letter
print(name[1])   # second letter
# Out:
# A
# k

# %%
word = "HelloWorld"
print(word[0:5])   # from index 0 to 4
print(word[5:])    # from index 5 to end
print(word[:5])    # from start to 4
# Out:
# Hello
# World
# Hello

# %%
text = "Python"
print(text[-1])    # last character
print(text[-2])    # second last
# Out:
# n
# o

# %%
first = "Aki"
last = "Konathala"
full = first + " " + last
print(full)
# Out:
# Aki Konathala

# %%
a = "Hi "
print(a * 3)
# Out:
# Hi Hi Hi

# %%
msg = "Hello Aki"
print(len(msg))
# Out:
# 9

# %%
sentence = "I love Python"
print("love" in sentence)     # True
print("hate" in sentence)     # False
# Out:
# True
# False

# %%
text = "Aki"
print(text.upper())
print(text.lower())
# Out:
# AKI
# aki

# %%
msg = "hello world"
print(msg.title())
# Out:
# Hello World

# %%
name = "   Aki   "
print(name.strip())
# Out:
# Aki

# %%
text = "I love apples"
print(text.replace("apples", "mangoes"))
# Out:
# I love mangoes

# %%
line = "Aki is learning Python"
words = line.split()
print(words)
# Out:
# ['Aki', 'is', 'learning', 'Python']

# %%
parts = ["Aki", "is", "smart"]
sentence = " ".join(parts)
print(sentence)
# Out:
# Aki is smart
