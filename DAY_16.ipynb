# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-7773/30-days-PYTHON/blob/main/DAY_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**MODULES**

# %%
# Using the math module
import math

print("Square root of 16:", math.sqrt(16))
print("Value of pi:", math.pi)
print("Ceiling of 4.7:", math.ceil(4.7))
print("Floor of 4.7:", math.floor(4.7))
# Out:
# Square root of 16: 4.0
# Value of pi: 3.141592653589793
# Ceiling of 4.7: 5
# Floor of 4.7: 4

# %%
import random

# Random number between 1 and 10
print("Random number:", random.randint(1, 10))

# Random choice from a list
fruits = ["apple", "banana", "cherry"]
print("Random fruit:", random.choice(fruits))

# Shuffle a list
random.shuffle(fruits)
print("Shuffled fruits:", fruits)
# Out:
# Random number: 7
# Random fruit: cherry
# Shuffled fruits: ['cherry', 'apple', 'banana']

# %%
import datetime

# Current date and time
now = datetime.datetime.now()
print("Current date and time:", now)

# Current year, month, day
print("Year:", now.year)
print("Month:", now.month)
print("Day:", now.day)
# Out:
# Current date and time: 2025-12-11 12:45:41.948750
# Year: 2025
# Month: 12
# Day: 11
