# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-7773/30-days-PYTHON/blob/main/DAY_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def name(name="akshitha"):
 print("welcome" ,name)
name("suda")
# Out:
# welcome suda

# %%
def add(x=10,y=5):
  sum=x+y
  print(sum)
add(4,5)
# Out:
# 9

# %%
def show_toy():
  toy="car"
  print(toy)
show_toy()
# Out:
# car

# %%
toy = "car"   # global variable

def show_toy():
    print(toy)

show_toy()
print(toy)
# Out:
# car
# car

# %%
score=100
def add_points(points=20):
  global score
  score+=points
  print(score)
add_points()
print(score)
# Out:
# 120
# 120

# %%
def outer():
  def inner():
    print("hello from inside")
  inner()
outer()
# Out:
# hello from inside

# %%
def greet_user(name="aki"):


  def message():
    print("have a great day",name)
  message()
greet_user()
greet_user("suda")
# Out:
# have a great day aki
# have a great day suda

# %%
def wish(name="akshitha"):
  def say():
    print("you are amazing",name)
  say()
wish()
wish("aki")
# Out:
# you are amazing akshitha
# you are amazing aki
