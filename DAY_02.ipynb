# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-7773/30-days-PYTHON/blob/main/DAY_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**BASIC PYTHON SYNTAX**

# %%
def greet():
    print("Hello!")

greet()
# Out:
# Hello!

# %%
user_age = 20
_user = "Aki"
value123 = 50

print(user_age, _user, value123)
# Out:
# 20 Aki 50

# %%
# invalid examples (cannot use):
# 1value = 5
# for = 10

# %%
x = 15
if x > 10:
    print("x is greater than 10")
else:
    print("x is 10 or less")
# Out:
# x is greater than 10

# %%
for i in range(1, 6):
    print("Loop value:", i)
# Out:
# Loop value: 1
# Loop value: 2
# Loop value: 3
# Loop value: 4
# Loop value: 5

# %%
import keyword
print("Python keywords:")
print(keyword.kwlist)
# Out:
# Python keywords:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a = 8
b = 3

print("Addition:", a + b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponent:", a ** b)
# Out:
# Addition: 11
# Floor Division: 2
# Modulus: 2
# Exponent: 512

# %%
text = "Python Syntax Day"
print(text.upper())
print(text.lower())
print(text[0:6])
# Out:
# PYTHON SYNTAX DAY
# python syntax day
# Python
