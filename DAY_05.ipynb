# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-7773/30-days-PYTHON/blob/main/DAY_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):
  print("akshitha")
# Out:
# akshitha
# akshitha
# akshitha
# akshitha
# akshitha

# %%
i=1
while i<10:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
password=str(input("enter a password"))
while password !=("python123"):
 print("incorrect password try again!")
 password=str(input("enter a password"))
 print("correct password")
# Out:
# enter a passwordaki
# incorrect password try again!
# enter a passwordpython123
# correct password

# %%
import random
secret_number=random.randint(1,5)

guess=int(input("enter your guess"))
while guess!=secret_number:
  print("incorrect guess, TRY AGAIN")
  guess=int(input("enter your guess"))
  if guess==secret_number:
   print ("correct guess")
# Out:
# enter your guess2
# incorrect guess, TRY AGAIN
# enter your guess3
# incorrect guess, TRY AGAIN
# enter your guess4
# incorrect guess, TRY AGAIN
# enter your guess5
# incorrect guess, TRY AGAIN
# enter your guess2
# incorrect guess, TRY AGAIN
# enter your guess1
# correct guess

# %%
password = input("Enter a password")
attempts = 3

while password != "python123" and attempts > 0:
    attempts -= 1
    print(f"wrong password you have {attempts} left")


    password = input("enter a password")

    if password != "python123":
        print("access denied")

    if attempts == 0:
        print("no more attempts")

# Final check after loop
if password == "python123":
    print("access granted")
# Out:
# Enter a password12
# wrong password you have 2 left
# enter a password34
# access denied
# wrong password you have 1 left
# enter a passwordpython123
# access granted

# %%
num = int(input("Enter a number: "))
i = 1

while i <= 10:
    print(f"{num} x {i} = {num * i}")
    i += 1
# Out:
# Enter a number: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
num=int(input("enter a number:"))
total=0
while num>=0:

  total+=num
  num=int(input("enter a number"))
  if num<0:
   print(total)
# Out:
# enter a number:2
# enter a number3
# enter a number4
# enter a number5
# enter a number-2
# 14
