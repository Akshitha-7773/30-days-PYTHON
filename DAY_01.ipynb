# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-7773/30-days-PYTHON/blob/main/DAY_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Introduction to Python**

# %%
print("Welcome to Day 1 of Python!")
# Out:
# Welcome to Day 1 of Python!

# %%
name = "Akshitha"
age = 19
height = 5.4

print("Name:", name)
print("Age:", age)
print("Height:", height)
# Out:
# Name: Akshitha
# Age: 19
# Height: 5.4

# %%
integer_num = 10
float_num = 3.14
string_text = "Hello Python"
boolean_value = True

print(type(integer_num))
print(type(float_num))
print(type(string_text))
print(type(boolean_value))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335

# %%
"""
This is a multi-line comment
You can write notes here
"""
# Out:
# '\nThis is a multi-line comment\nYou can write notes here\n'
